# %%
import numpy as np
import pandas as pd
import sklearn
from sklearn import linear_model

# %%
data = pd.read_csv("student-mat.csv", sep=";")
data = data[["G1", "G2", "G3", "studytime", "failures", "absences"]]

predict = "G3"

x = np.array(data.drop([predict], 1))
y = np.array(data[predict])

x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(x, y, test_size=0.1)

linear = linear_model.LinearRegression()

linear.fit(x_train, y_train)

accuracy = linear.score(x_test,y_test)
print("Model Accuracy: ", accuracy)

print("Coefficient: ", linear.coef_) #We have a 5 dimensional space here so we have 5 Coefficients! (our line starting position depending on 5 axis )
print("Intercept: ", linear.intercept_) # y

print("\n\n#####################################")
predictions = linear.predict(x_test)
for i in range(len(predictions)):
    print(f"Data #{i+1}")
    print("Model Prediction: ", predictions[i])
    print("Input Data: ", x_test[i])
    print("Real Label: ", y_test[i])
    print("#####################################")
# Out:
# Model Accuracy:  0.7338789388801772
# Coefficient:  [ 0.14080948  0.9834471  -0.23815192 -0.30036232  0.03282668]
# Intercept:  -1.2219170034987457
#
#
# #####################################
# Data #1
# Model Prediction:  18.744860429782598
# Input Data:  [19 18  2  0  2]
# Real Label:  18
# #####################################
# Data #2
# Model Prediction:  9.45968607430011
# Input Data:  [ 8 10  2  0  6]
# Real Label:  10
# #####################################
# Data #3
# Model Prediction:  4.7938663140511775
# Input Data:  [8 6 2 2 2]
# Real Label:  5
# #####################################
# Data #4
# Model Prediction:  12.581620337687895
# Input Data:  [14 13  4  0  0]
# Real Label:  14
# #####################################
# Data #5
# Model Prediction:  4.761596953765984
# Input Data:  [ 6  5  1  0 14]
# Real Label:  5
# #####################################
# Data #6
# Model Prediction:  11.724773396980472
# Input Data:  [13 11  3  1 40]
# Real Label:  11
# #####################################
# Data #7
# Model Prediction:  12.293623463488478
# Input Data:  [12 12  1  0  8]
# Real Label:  12
# #####################################
# Data #8
# Model Prediction:  9.29669027630225
# Input Data:  [ 9 10  3  0  4]
# Real Label:  10
# #####################################
# Data #9
# Model Prediction:  7.295831798084292
# Input Data:  [8 8 2 0 0]
# Real Label:  0
# #####################################
# Data #10
# Model Prediction:  18.973509584851417
# Input Data:  [18 18  1  0  6]
# Real Label:  18
# #####################################
# Data #11
# Model Prediction:  8.518784072313096
# Input Data:  [ 8  8  1  0 30]
# Real Label:  8
# #####################################
# Data #12
# Model Prediction:  12.356151977188233
# Input Data:  [11 13  4  0  6]
# Real Label:  14
# #####################################
# Data #13
# Model Prediction:  5.936866257365701
# Input Data:  [7 7 2 1 2]
# Real Label:  7
# #####################################
# Data #14
# Model Prediction:  11.890200557967129
# Input Data:  [11 12  1  0  0]
# Real Label:  10
# #####################################
# Data #15
# Model Prediction:  12.982768053850169
# Input Data:  [13 13  2  0  2]
# Real Label:  13
# #####################################
# Data #16
# Model Prediction:  11.858511474111186
# Input Data:  [12 12  2  0  2]
# Real Label:  11
# #####################################
# Data #17
# Model Prediction:  13.376688196275925
# Input Data:  [13 13  2  0 14]
# Real Label:  14
# #####################################
# Data #18
# Model Prediction:  10.668601537301242
# Input Data:  [11 11  2  0  0]
# Real Label:  10
# #####################################
# Data #19
# Model Prediction:  10.79990825144316
# Input Data:  [11 11  2  0  4]
# Real Label:  11
# #####################################
# Data #20
# Model Prediction:  12.982768053850169
# Input Data:  [13 13  2  0  2]
# Real Label:  13
# #####################################
# Data #21
# Model Prediction:  9.675651671704177
# Input Data:  [10 10  2  0  4]
# Real Label:  11
# #####################################
# Data #22
# Model Prediction:  20.08826340149481
# Input Data:  [18 19  1  0 10]
# Real Label:  19
# #####################################
# Data #23
# Model Prediction:  8.13846942334825
# Input Data:  [7 9 2 0 0]
# Real Label:  8
# #####################################
# Data #24
# Model Prediction:  9.243982639511692
# Input Data:  [10 10  2  1  0]
# Real Label:  0
# #####################################
# Data #25
# Model Prediction:  18.256778640999098
# Input Data:  [16 18  2  0  0]
# Real Label:  19
# #####################################
# Data #26
# Model Prediction:  10.088577340321121
# Input Data:  [12 10  2  0  8]
# Real Label:  11
# #####################################
# Data #27
# Model Prediction:  8.119726059772708
# Input Data:  [9 9 2 1 0]
# Real Label:  0
# #####################################
# Data #28
# Model Prediction:  10.593445417134689
# Input Data:  [10 11  2  0  2]
# Real Label:  11
# #####################################
# Data #29
# Model Prediction:  8.968081831580548
# Input Data:  [10 10  3  2  8]
# Real Label:  10
# #####################################
# Data #30
# Model Prediction:  10.659098774205647
# Input Data:  [10 11  2  0  4]
# Real Label:  9
# #####################################
# Data #31
# Model Prediction:  8.692204569202707
# Input Data:  [10  9  2  0  4]
# Real Label:  9
# #####################################
# Data #32
# Model Prediction:  6.970666310547394
# Input Data:  [9 8 1 3 6]
# Real Label:  10
# #####################################
# Data #33
# Model Prediction:  -0.2901260674524466
# Input Data:  [10  0  2  0  0]
# Real Label:  0
# #####################################
# Data #34
# Model Prediction:  9.380427223768242
# Input Data:  [ 9  9  1  0 22]
# Real Label:  9
# #####################################
# Data #35
# Model Prediction:  7.147794747110261
# Input Data:  [ 8  8  4  0 10]
# Real Label:  8
# #####################################
# Data #36
# Model Prediction:  13.235878719038412
# Input Data:  [12 13  2  0 14]
# Real Label:  12
# #####################################
# Data #37
# Model Prediction:  8.320129088170393
# Input Data:  [9 9 1 2 8]
# Real Label:  9
# #####################################
# Data #38
# Model Prediction:  15.059920246914217
# Input Data:  [16 15  4  0  7]
# Real Label:  17
# #####################################
# Data #39
# Model Prediction:  15.361450332790518
# Input Data:  [14 15  1  0  3]
# Real Label:  16
# #####################################
# Data #40
# Model Prediction:  5.9334233001808965
# Input Data:  [7 7 3 0 0]
# Real Label:  8
# #####################################
