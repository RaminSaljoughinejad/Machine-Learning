# %%
import numpy as np
import pandas as pd
import sklearn
from sklearn.utils import shuffle
from sklearn.neighbors import KNeighborsClassifier
from sklearn import linear_model, preprocessing
import pickle

# %%
data = pd.read_csv("car.data")
#print(data.head())

myPreprocessor = preprocessing.LabelEncoder()
buying = myPreprocessor.fit_transform(list(data["buying"]))
maint = myPreprocessor.fit_transform(list(data["maint"]))
door = myPreprocessor.fit_transform(list(data["door"]))
persons = myPreprocessor.fit_transform(list(data["persons"]))
lug_boot = myPreprocessor.fit_transform(list(data["lug_boot"]))
safety = myPreprocessor.fit_transform(list(data["safety"]))
clas = myPreprocessor.fit_transform(list(data["class"]))

predit = "class"

x = list(zip(buying, maint, door, lug_boot, safety))
y = list(clas)

best = 0
for _ in range(30):
    x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(x, y, test_size=0.1)

    model = KNeighborsClassifier(n_neighbors=9)
    model.fit(x_train,y_train)

    accuracy = model.score(x_test, y_test)
    if accuracy > best:
        best = accuracy
        with open("carModel.pickle", "wb") as modelFile:
            pickle.dump(model, modelFile)
print("Best Accuracy: ",best)

predicted = model.predict(x_test)
names = ["unacc", "acc", "good", "vgood"]

print("\n\n#################################")
for i in range(len(predicted)):
    print(f"Data #{i+1}")
    print("Model Prediction: ", names[predicted[i]])
    print("Input Data: ", x_test[i])
    print("Real Label: ", names[y_test[i]])
    print("#################################")
# Out:
# Best Accuracy:  0.7514450867052023
#
#
# #################################
# Data #1
# Model Prediction:  good
# Input Data:  (2, 0, 3, 0, 0)
# Real Label:  good
# #################################
# Data #2
# Model Prediction:  good
# Input Data:  (1, 1, 1, 1, 0)
# Real Label:  good
# #################################
# Data #3
# Model Prediction:  unacc
# Input Data:  (3, 2, 2, 1, 2)
# Real Label:  good
# #################################
# Data #4
# Model Prediction:  good
# Input Data:  (2, 1, 2, 2, 0)
# Real Label:  good
# #################################
# Data #5
# Model Prediction:  good
# Input Data:  (3, 0, 1, 2, 1)
# Real Label:  good
# #################################
# Data #6
# Model Prediction:  good
# Input Data:  (3, 3, 0, 0, 1)
# Real Label:  good
# #################################
# Data #7
# Model Prediction:  good
# Input Data:  (2, 1, 2, 2, 0)
# Real Label:  acc
# #################################
# Data #8
# Model Prediction:  good
# Input Data:  (1, 0, 2, 2, 1)
# Real Label:  good
# #################################
# Data #9
# Model Prediction:  unacc
# Input Data:  (3, 2, 3, 0, 2)
# Real Label:  unacc
# #################################
# Data #10
# Model Prediction:  good
# Input Data:  (1, 1, 0, 1, 1)
# Real Label:  good
# #################################
# Data #11
# Model Prediction:  good
# Input Data:  (2, 3, 0, 1, 1)
# Real Label:  good
# #################################
# Data #12
# Model Prediction:  good
# Input Data:  (0, 2, 1, 0, 2)
# Real Label:  unacc
# #################################
# Data #13
# Model Prediction:  good
# Input Data:  (0, 2, 2, 1, 1)
# Real Label:  good
# #################################
# Data #14
# Model Prediction:  good
# Input Data:  (3, 1, 2, 2, 2)
# Real Label:  good
# #################################
# Data #15
# Model Prediction:  good
# Input Data:  (3, 1, 2, 2, 0)
# Real Label:  good
# #################################
# Data #16
# Model Prediction:  good
# Input Data:  (3, 1, 3, 2, 1)
# Real Label:  good
# #################################
# Data #17
# Model Prediction:  good
# Input Data:  (3, 2, 3, 0, 0)
# Real Label:  unacc
# #################################
# Data #18
# Model Prediction:  unacc
# Input Data:  (2, 3, 0, 2, 0)
# Real Label:  good
# #################################
# Data #19
# Model Prediction:  good
# Input Data:  (1, 2, 2, 1, 0)
# Real Label:  vgood
# #################################
# Data #20
# Model Prediction:  good
# Input Data:  (1, 1, 3, 2, 2)
# Real Label:  unacc
# #################################
# Data #21
# Model Prediction:  good
# Input Data:  (1, 1, 0, 1, 2)
# Real Label:  unacc
# #################################
# Data #22
# Model Prediction:  good
# Input Data:  (1, 3, 0, 2, 0)
# Real Label:  good
# #################################
# Data #23
# Model Prediction:  unacc
# Input Data:  (0, 0, 3, 1, 0)
# Real Label:  good
# #################################
# Data #24
# Model Prediction:  unacc
# Input Data:  (0, 1, 1, 2, 0)
# Real Label:  unacc
# #################################
# Data #25
# Model Prediction:  good
# Input Data:  (2, 3, 1, 2, 0)
# Real Label:  unacc
# #################################
# Data #26
# Model Prediction:  good
# Input Data:  (3, 0, 1, 0, 1)
# Real Label:  good
# #################################
# Data #27
# Model Prediction:  good
# Input Data:  (1, 0, 0, 0, 0)
# Real Label:  vgood
# #################################
# Data #28
# Model Prediction:  good
# Input Data:  (1, 0, 2, 0, 2)
# Real Label:  unacc
# #################################
# Data #29
# Model Prediction:  good
# Input Data:  (1, 3, 1, 2, 0)
# Real Label:  unacc
# #################################
# Data #30
# Model Prediction:  unacc
# Input Data:  (2, 3, 0, 2, 0)
# Real Label:  good
# #################################
# Data #31
# Model Prediction:  good
# Input Data:  (0, 2, 3, 2, 1)
# Real Label:  good
# #################################
# Data #32
# Model Prediction:  good
# Input Data:  (3, 1, 2, 2, 1)
# Real Label:  good
# #################################
# Data #33
# Model Prediction:  good
# Input Data:  (0, 0, 0, 1, 1)
# Real Label:  good
# #################################
# Data #34
# Model Prediction:  good
# Input Data:  (1, 1, 2, 1, 0)
# Real Label:  vgood
# #################################
# Data #35
# Model Prediction:  good
# Input Data:  (2, 1, 0, 2, 1)
# Real Label:  good
# #################################
# Data #36
# Model Prediction:  good
# Input Data:  (3, 1, 0, 0, 1)
# Real Label:  good
# #################################
# Data #37
# Model Prediction:  unacc
# Input Data:  (0, 0, 3, 1, 0)
# Real Label:  unacc
# #################################
# Data #38
# Model Prediction:  good
# Input Data:  (1, 2, 2, 0, 2)
# Real Label:  acc
# #################################
# Data #39
# Model Prediction:  good
# Input Data:  (3, 1, 1, 1, 2)
# Real Label:  good
# #################################
# Data #40
# Model Prediction:  good
# Input Data:  (2, 0, 0, 0, 1)
# Real Label:  good
# #################################
# Data #41
# Model Prediction:  unacc
# Input Data:  (0, 0, 3, 0, 2)
# Real Label:  good
# #################################
# Data #42
# Model Prediction:  good
# Input Data:  (3, 0, 0, 2, 0)
# Real Label:  good
# #################################
# Data #43
# Model Prediction:  good
# Input Data:  (3, 0, 1, 1, 1)
# Real Label:  good
# #################################
# Data #44
# Model Prediction:  good
# Input Data:  (2, 0, 3, 2, 2)
# Real Label:  good
# #################################
# Data #45
# Model Prediction:  good
# Input Data:  (2, 3, 1, 1, 2)
# Real Label:  unacc
# #################################
# Data #46
# Model Prediction:  good
# Input Data:  (3, 1, 0, 0, 1)
# Real Label:  good
# #################################
# Data #47
# Model Prediction:  unacc
# Input Data:  (2, 2, 0, 1, 2)
# Real Label:  good
# #################################
# Data #48
# Model Prediction:  good
# Input Data:  (2, 2, 0, 2, 0)
# Real Label:  good
# #################################
# Data #49
# Model Prediction:  unacc
# Input Data:  (1, 0, 1, 1, 2)
# Real Label:  unacc
# #################################
# Data #50
# Model Prediction:  good
# Input Data:  (1, 2, 0, 1, 0)
# Real Label:  acc
# #################################
# Data #51
# Model Prediction:  good
# Input Data:  (3, 2, 0, 2, 1)
# Real Label:  good
# #################################
# Data #52
# Model Prediction:  good
# Input Data:  (2, 2, 0, 1, 1)
# Real Label:  good
# #################################
# Data #53
# Model Prediction:  good
# Input Data:  (2, 2, 2, 0, 1)
# Real Label:  good
# #################################
# Data #54
# Model Prediction:  good
# Input Data:  (0, 3, 3, 0, 1)
# Real Label:  good
# #################################
# Data #55
# Model Prediction:  good
# Input Data:  (3, 1, 2, 1, 2)
# Real Label:  good
# #################################
# Data #56
# Model Prediction:  good
# Input Data:  (1, 2, 0, 0, 2)
# Real Label:  acc
# #################################
# Data #57
# Model Prediction:  unacc
# Input Data:  (3, 2, 0, 0, 2)
# Real Label:  good
# #################################
# Data #58
# Model Prediction:  good
# Input Data:  (1, 3, 0, 2, 0)
# Real Label:  unacc
# #################################
# Data #59
# Model Prediction:  good
# Input Data:  (3, 1, 3, 2, 2)
# Real Label:  good
# #################################
# Data #60
# Model Prediction:  good
# Input Data:  (1, 2, 2, 0, 2)
# Real Label:  acc
# #################################
# Data #61
# Model Prediction:  good
# Input Data:  (0, 3, 1, 0, 0)
# Real Label:  good
# #################################
# Data #62
# Model Prediction:  good
# Input Data:  (1, 2, 3, 2, 0)
# Real Label:  acc
# #################################
# Data #63
# Model Prediction:  good
# Input Data:  (1, 3, 2, 1, 0)
# Real Label:  unacc
# #################################
# Data #64
# Model Prediction:  acc
# Input Data:  (2, 1, 2, 1, 2)
# Real Label:  good
# #################################
# Data #65
# Model Prediction:  good
# Input Data:  (0, 2, 1, 1, 2)
# Real Label:  good
# #################################
# Data #66
# Model Prediction:  good
# Input Data:  (2, 1, 3, 0, 1)
# Real Label:  good
# #################################
# Data #67
# Model Prediction:  good
# Input Data:  (2, 0, 0, 1, 2)
# Real Label:  good
# #################################
# Data #68
# Model Prediction:  good
# Input Data:  (0, 2, 1, 0, 1)
# Real Label:  good
# #################################
# Data #69
# Model Prediction:  unacc
# Input Data:  (2, 3, 3, 0, 2)
# Real Label:  unacc
# #################################
# Data #70
# Model Prediction:  unacc
# Input Data:  (2, 2, 3, 0, 2)
# Real Label:  good
# #################################
# Data #71
# Model Prediction:  unacc
# Input Data:  (1, 1, 3, 1, 2)
# Real Label:  acc
# #################################
# Data #72
# Model Prediction:  good
# Input Data:  (1, 1, 0, 1, 0)
# Real Label:  acc
# #################################
# Data #73
# Model Prediction:  good
# Input Data:  (2, 1, 0, 1, 0)
# Real Label:  good
# #################################
# Data #74
# Model Prediction:  good
# Input Data:  (1, 3, 2, 2, 2)
# Real Label:  good
# #################################
# Data #75
# Model Prediction:  good
# Input Data:  (0, 2, 2, 0, 0)
# Real Label:  unacc
# #################################
# Data #76
# Model Prediction:  good
# Input Data:  (0, 1, 1, 1, 1)
# Real Label:  good
# #################################
# Data #77
# Model Prediction:  good
# Input Data:  (3, 3, 1, 1, 1)
# Real Label:  good
# #################################
# Data #78
# Model Prediction:  good
# Input Data:  (2, 3, 0, 2, 1)
# Real Label:  good
# #################################
# Data #79
# Model Prediction:  good
# Input Data:  (2, 1, 1, 0, 1)
# Real Label:  good
# #################################
# Data #80
# Model Prediction:  good
# Input Data:  (0, 1, 3, 1, 1)
# Real Label:  good
# #################################
# Data #81
# Model Prediction:  good
# Input Data:  (3, 1, 2, 0, 1)
# Real Label:  good
# #################################
# Data #82
# Model Prediction:  good
# Input Data:  (2, 2, 2, 0, 2)
# Real Label:  unacc
# #################################
# Data #83
# Model Prediction:  good
# Input Data:  (0, 2, 2, 1, 2)
# Real Label:  unacc
# #################################
# Data #84
# Model Prediction:  good
# Input Data:  (3, 2, 1, 2, 0)
# Real Label:  unacc
# #################################
# Data #85
# Model Prediction:  good
# Input Data:  (3, 0, 0, 1, 2)
# Real Label:  good
# #################################
# Data #86
# Model Prediction:  good
# Input Data:  (0, 1, 0, 0, 1)
# Real Label:  good
# #################################
# Data #87
# Model Prediction:  good
# Input Data:  (1, 3, 2, 2, 0)
# Real Label:  good
# #################################
# Data #88
# Model Prediction:  good
# Input Data:  (0, 2, 2, 0, 2)
# Real Label:  unacc
# #################################
# Data #89
# Model Prediction:  unacc
# Input Data:  (0, 0, 2, 1, 2)
# Real Label:  unacc
# #################################
# Data #90
# Model Prediction:  good
# Input Data:  (1, 0, 0, 2, 0)
# Real Label:  unacc
# #################################
# Data #91
# Model Prediction:  good
# Input Data:  (2, 0, 3, 0, 0)
# Real Label:  unacc
# #################################
# Data #92
# Model Prediction:  good
# Input Data:  (3, 0, 2, 2, 2)
# Real Label:  good
# #################################
# Data #93
# Model Prediction:  good
# Input Data:  (3, 1, 2, 0, 1)
# Real Label:  good
# #################################
# Data #94
# Model Prediction:  good
# Input Data:  (3, 0, 4, 0, 0)
# Real Label:  good
# #################################
# Data #95
# Model Prediction:  good
# Input Data:  (2, 0, 2, 1, 1)
# Real Label:  good
# #################################
# Data #96
# Model Prediction:  good
# Input Data:  (1, 3, 2, 2, 1)
# Real Label:  good
# #################################
# Data #97
# Model Prediction:  good
# Input Data:  (1, 0, 3, 1, 1)
# Real Label:  good
# #################################
# Data #98
# Model Prediction:  good
# Input Data:  (3, 0, 1, 0, 1)
# Real Label:  good
# #################################
# Data #99
# Model Prediction:  good
# Input Data:  (3, 0, 4, 1, 0)
# Real Label:  good
# #################################
# Data #100
# Model Prediction:  good
# Input Data:  (3, 2, 3, 0, 1)
# Real Label:  good
# #################################
# Data #101
# Model Prediction:  good
# Input Data:  (3, 0, 4, 0, 2)
# Real Label:  good
# #################################
# Data #102
# Model Prediction:  good
# Input Data:  (3, 3, 3, 0, 1)
# Real Label:  good
# #################################
# Data #103
# Model Prediction:  good
# Input Data:  (3, 2, 2, 1, 1)
# Real Label:  good
# #################################
# Data #104
# Model Prediction:  good
# Input Data:  (2, 3, 1, 0, 1)
# Real Label:  good
# #################################
# Data #105
# Model Prediction:  unacc
# Input Data:  (1, 3, 3, 1, 0)
# Real Label:  good
# #################################
# Data #106
# Model Prediction:  good
# Input Data:  (2, 0, 1, 1, 1)
# Real Label:  good
# #################################
# Data #107
# Model Prediction:  good
# Input Data:  (1, 1, 1, 0, 0)
# Real Label:  vgood
# #################################
# Data #108
# Model Prediction:  good
# Input Data:  (1, 0, 3, 2, 1)
# Real Label:  good
# #################################
# Data #109
# Model Prediction:  good
# Input Data:  (3, 3, 1, 2, 0)
# Real Label:  good
# #################################
# Data #110
# Model Prediction:  good
# Input Data:  (0, 1, 0, 1, 0)
# Real Label:  unacc
# #################################
# Data #111
# Model Prediction:  good
# Input Data:  (0, 3, 0, 1, 0)
# Real Label:  good
# #################################
# Data #112
# Model Prediction:  good
# Input Data:  (2, 3, 3, 0, 1)
# Real Label:  good
# #################################
# Data #113
# Model Prediction:  good
# Input Data:  (0, 2, 3, 0, 0)
# Real Label:  unacc
# #################################
# Data #114
# Model Prediction:  good
# Input Data:  (0, 2, 2, 0, 1)
# Real Label:  good
# #################################
# Data #115
# Model Prediction:  good
# Input Data:  (3, 0, 2, 2, 2)
# Real Label:  good
# #################################
# Data #116
# Model Prediction:  good
# Input Data:  (3, 3, 2, 2, 0)
# Real Label:  good
# #################################
# Data #117
# Model Prediction:  good
# Input Data:  (2, 3, 0, 2, 1)
# Real Label:  good
# #################################
# Data #118
# Model Prediction:  good
# Input Data:  (3, 0, 2, 2, 0)
# Real Label:  good
# #################################
# Data #119
# Model Prediction:  good
# Input Data:  (0, 3, 3, 0, 2)
# Real Label:  good
# #################################
# Data #120
# Model Prediction:  good
# Input Data:  (3, 0, 2, 0, 0)
# Real Label:  good
# #################################
# Data #121
# Model Prediction:  good
# Input Data:  (1, 1, 0, 2, 2)
# Real Label:  unacc
# #################################
# Data #122
# Model Prediction:  good
# Input Data:  (0, 1, 1, 1, 1)
# Real Label:  good
# #################################
# Data #123
# Model Prediction:  unacc
# Input Data:  (2, 1, 1, 1, 2)
# Real Label:  good
# #################################
# Data #124
# Model Prediction:  good
# Input Data:  (2, 2, 2, 0, 1)
# Real Label:  good
# #################################
# Data #125
# Model Prediction:  good
# Input Data:  (1, 1, 3, 0, 2)
# Real Label:  good
# #################################
# Data #126
# Model Prediction:  good
# Input Data:  (2, 2, 2, 2, 0)
# Real Label:  unacc
# #################################
# Data #127
# Model Prediction:  acc
# Input Data:  (2, 1, 3, 0, 2)
# Real Label:  acc
# #################################
# Data #128
# Model Prediction:  good
# Input Data:  (3, 0, 1, 2, 0)
# Real Label:  good
# #################################
# Data #129
# Model Prediction:  good
# Input Data:  (1, 0, 1, 2, 1)
# Real Label:  good
# #################################
# Data #130
# Model Prediction:  good
# Input Data:  (3, 3, 3, 1, 1)
# Real Label:  good
# #################################
# Data #131
# Model Prediction:  good
# Input Data:  (0, 1, 1, 0, 1)
# Real Label:  good
# #################################
# Data #132
# Model Prediction:  good
# Input Data:  (1, 0, 2, 2, 2)
# Real Label:  unacc
# #################################
# Data #133
# Model Prediction:  good
# Input Data:  (1, 3, 0, 2, 0)
# Real Label:  good
# #################################
# Data #134
# Model Prediction:  unacc
# Input Data:  (2, 0, 3, 1, 0)
# Real Label:  unacc
# #################################
# Data #135
# Model Prediction:  good
# Input Data:  (1, 0, 0, 1, 1)
# Real Label:  good
# #################################
# Data #136
# Model Prediction:  good
# Input Data:  (3, 2, 3, 2, 2)
# Real Label:  good
# #################################
# Data #137
# Model Prediction:  good
# Input Data:  (3, 0, 2, 1, 0)
# Real Label:  good
# #################################
# Data #138
# Model Prediction:  good
# Input Data:  (2, 0, 0, 0, 0)
# Real Label:  unacc
# #################################
# Data #139
# Model Prediction:  good
# Input Data:  (3, 1, 1, 1, 1)
# Real Label:  good
# #################################
# Data #140
# Model Prediction:  good
# Input Data:  (3, 3, 3, 1, 0)
# Real Label:  good
# #################################
# Data #141
# Model Prediction:  good
# Input Data:  (1, 1, 2, 2, 0)
# Real Label:  acc
# #################################
# Data #142
# Model Prediction:  good
# Input Data:  (2, 0, 0, 2, 2)
# Real Label:  good
# #################################
# Data #143
# Model Prediction:  good
# Input Data:  (0, 2, 3, 0, 0)
# Real Label:  unacc
# #################################
# Data #144
# Model Prediction:  good
# Input Data:  (3, 0, 2, 2, 1)
# Real Label:  good
# #################################
# Data #145
# Model Prediction:  good
# Input Data:  (3, 0, 4, 2, 0)
# Real Label:  good
# #################################
# Data #146
# Model Prediction:  unacc
# Input Data:  (0, 1, 3, 1, 0)
# Real Label:  good
# #################################
# Data #147
# Model Prediction:  good
# Input Data:  (3, 1, 0, 0, 1)
# Real Label:  good
# #################################
# Data #148
# Model Prediction:  good
# Input Data:  (3, 3, 3, 2, 2)
# Real Label:  good
# #################################
# Data #149
# Model Prediction:  good
# Input Data:  (3, 3, 3, 2, 0)
# Real Label:  good
# #################################
# Data #150
# Model Prediction:  unacc
# Input Data:  (0, 0, 0, 1, 0)
# Real Label:  unacc
# #################################
# Data #151
# Model Prediction:  good
# Input Data:  (0, 0, 2, 1, 1)
# Real Label:  good
# #################################
# Data #152
# Model Prediction:  good
# Input Data:  (1, 1, 2, 0, 2)
# Real Label:  good
# #################################
# Data #153
# Model Prediction:  acc
# Input Data:  (1, 2, 3, 1, 2)
# Real Label:  acc
# #################################
# Data #154
# Model Prediction:  good
# Input Data:  (0, 2, 0, 2, 0)
# Real Label:  good
# #################################
# Data #155
# Model Prediction:  good
# Input Data:  (1, 1, 2, 0, 0)
# Real Label:  good
# #################################
# Data #156
# Model Prediction:  good
# Input Data:  (2, 2, 1, 0, 1)
# Real Label:  good
# #################################
# Data #157
# Model Prediction:  good
# Input Data:  (0, 1, 0, 1, 1)
# Real Label:  good
# #################################
# Data #158
# Model Prediction:  good
# Input Data:  (0, 0, 0, 2, 1)
# Real Label:  good
# #################################
# Data #159
# Model Prediction:  unacc
# Input Data:  (0, 1, 2, 0, 0)
# Real Label:  good
# #################################
# Data #160
# Model Prediction:  good
# Input Data:  (3, 3, 3, 2, 2)
# Real Label:  good
# #################################
# Data #161
# Model Prediction:  unacc
# Input Data:  (0, 0, 1, 2, 0)
# Real Label:  unacc
# #################################
# Data #162
# Model Prediction:  good
# Input Data:  (1, 3, 0, 2, 1)
# Real Label:  good
# #################################
# Data #163
# Model Prediction:  good
# Input Data:  (0, 0, 1, 0, 1)
# Real Label:  good
# #################################
# Data #164
# Model Prediction:  good
# Input Data:  (1, 0, 2, 2, 0)
# Real Label:  unacc
# #################################
# Data #165
# Model Prediction:  good
# Input Data:  (2, 1, 1, 1, 1)
# Real Label:  good
# #################################
# Data #166
# Model Prediction:  good
# Input Data:  (3, 2, 1, 1, 1)
# Real Label:  good
# #################################
# Data #167
# Model Prediction:  good
# Input Data:  (2, 2, 0, 2, 2)
# Real Label:  good
# #################################
# Data #168
# Model Prediction:  good
# Input Data:  (3, 3, 2, 1, 0)
# Real Label:  good
# #################################
# Data #169
# Model Prediction:  good
# Input Data:  (2, 0, 0, 1, 0)
# Real Label:  unacc
# #################################
# Data #170
# Model Prediction:  good
# Input Data:  (2, 1, 1, 2, 0)
# Real Label:  acc
# #################################
# Data #171
# Model Prediction:  good
# Input Data:  (1, 0, 2, 2, 0)
# Real Label:  unacc
# #################################
# Data #172
# Model Prediction:  good
# Input Data:  (3, 3, 3, 0, 2)
# Real Label:  good
# #################################
# Data #173
# Model Prediction:  good
# Input Data:  (0, 3, 3, 2, 2)
# Real Label:  good
# #################################
