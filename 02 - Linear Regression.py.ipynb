# %%
import numpy as np
import pandas as pd
import sklearn
from sklearn import linear_model
import pickle

# %%
# Data Preparation
data = pd.read_csv("student-mat.csv", sep=";")
data = data[["G1", "G2", "G3", "studytime", "failures", "absences"]]
predict = "G3"
x = np.array(data.drop([predict], 1))
y = np.array(data[predict])
x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(x, y, test_size=0.1)


##############################

pickle_in = open("studentGradeModel.pickle", "rb")
linear = pickle.load(pickle_in)

###############################

accuracy = linear.score(x_test,y_test)
print("Model Accuracy: ", accuracy)
print("Coefficient: ", linear.coef_) #We have a 5 dimensional space here so we have 5 Coefficients! (our line starting position depending on 5 axis )
print("Intercept: ", linear.intercept_) # y

print("\n\n#####################################")
predictions = linear.predict(x_test)
for i in range(len(predictions)):
    print(f"Data #{i+1}")
    print("Model Prediction: ", predictions[i])
    print("Input Data: ", x_test[i])
    print("Real Label: ", y_test[i])
    print("#####################################")
# Out:
# Model Accuracy:  0.7442232813786014
# Coefficient:  [ 0.14915438  0.97858197 -0.18705036 -0.25739415  0.03514419]
# Intercept:  -1.4132846299271602
#
#
# #####################################
# Data #1
# Model Prediction:  8.283375752469581
# Input Data:  [8 9 2 0 2]
# Real Label:  10
# #####################################
# Data #2
# Model Prediction:  8.13729541115293
# Input Data:  [10  9  4  0  0]
# Real Label:  0
# #####################################
# Data #3
# Model Prediction:  6.442973803083422
# Input Data:  [8 7 1 0 0]
# Real Label:  6
# #####################################
# Data #4
# Model Prediction:  8.400137733521296
# Input Data:  [8 9 1 0 0]
# Real Label:  8
# #####################################
# Data #5
# Model Prediction:  14.173892634393566
# Input Data:  [15 14  3  0  6]
# Real Label:  14
# #####################################
# Data #6
# Model Prediction:  8.104847602006181
# Input Data:  [9 9 2 1 0]
# Real Label:  0
# #####################################
# Data #7
# Model Prediction:  3.7051606213346213
# Input Data:  [7 5 3 1 0]
# Real Label:  0
# #####################################
# Data #8
# Model Prediction:  5.873245100811563
# Input Data:  [7 7 4 0 4]
# Real Label:  6
# #####################################
# Data #9
# Model Prediction:  15.771037046736067
# Input Data:  [14 16  3  0  0]
# Real Label:  16
# #####################################
# Data #10
# Model Prediction:  14.258262216869612
# Input Data:  [14 14  1  0  2]
# Real Label:  13
# #####################################
# Data #11
# Model Prediction:  11.707499395661856
# Input Data:  [13 12  2  1  2]
# Real Label:  12
# #####################################
# Data #12
# Model Prediction:  5.049321097558004
# Input Data:  [6 6 2 0 2]
# Real Label:  6
# #####################################
# Data #13
# Model Prediction:  13.092629891109631
# Input Data:  [14 13  2  0  2]
# Real Label:  13
# #####################################
# Data #14
# Model Prediction:  12.8236394921198
# Input Data:  [10 13  1  0  6]
# Real Label:  13
# #####################################
# Data #15
# Model Prediction:  3.991873132201012
# Input Data:  [5 5 2 0 4]
# Real Label:  6
# #####################################
# Data #16
# Model Prediction:  9.519296457718891
# Input Data:  [ 8 10  1  0  4]
# Real Label:  10
# #####################################
# Data #17
# Model Prediction:  8.374616297574699
# Input Data:  [ 9  9  2  2 15]
# Real Label:  9
# #####################################
# Data #18
# Model Prediction:  15.99047980585278
# Input Data:  [15 16  3  0  2]
# Real Label:  18
# #####################################
# Data #19
# Model Prediction:  8.071306425003774
# Input Data:  [10  8  1  0 10]
# Real Label:  9
# #####################################
# Data #20
# Model Prediction:  2.843285226596321
# Input Data:  [7 4 1 2 0]
# Real Label:  0
# #####################################
# Data #21
# Model Prediction:  8.862838029681667
# Input Data:  [10  9  2  0 10]
# Real Label:  10
# #####################################
# Data #22
# Model Prediction:  4.679519769816088
# Input Data:  [ 6  5  1  0 14]
# Real Label:  5
# #####################################
# Data #23
# Model Prediction:  11.853635147549587
# Input Data:  [11 12  1  0  2]
# Real Label:  11
# #####################################
# Data #24
# Model Prediction:  12.686136771451872
# Input Data:  [13 13  3  0  0]
# Real Label:  14
# #####################################
# Data #25
# Model Prediction:  8.760157251616668
# Input Data:  [9 9 1 0 6]
# Real Label:  10
# #####################################
# Data #26
# Model Prediction:  16.44344652707293
# Input Data:  [16 16  1  0  0]
# Real Label:  15
# #####################################
# Data #27
# Model Prediction:  9.191669338199187
# Input Data:  [ 8 10  2  0  0]
# Real Label:  12
# #####################################
# Data #28
# Model Prediction:  15.049793821547505
# Input Data:  [14 15  2  0  2]
# Real Label:  15
# #####################################
# Data #29
# Model Prediction:  7.876882632811823
# Input Data:  [7 9 3 0 0]
# Real Label:  8
# #####################################
# Data #30
# Model Prediction:  12.794321131854863
# Input Data:  [12 13  2  0  2]
# Real Label:  12
# #####################################
# Data #31
# Model Prediction:  9.592658875518955
# Input Data:  [11 10  3  0  4]
# Real Label:  10
# #####################################
# Data #32
# Model Prediction:  5.764894508695332
# Input Data:  [8 7 2 3 8]
# Real Label:  8
# #####################################
# Data #33
# Model Prediction:  10.536096650993224
# Input Data:  [11 11  3  0  3]
# Real Label:  11
# #####################################
# Data #34
# Model Prediction:  13.889665078125514
# Input Data:  [12 14  1  0  0]
# Real Label:  15
# #####################################
# Data #35
# Model Prediction:  12.06751891375723
# Input Data:  [14 12  2  1  8]
# Real Label:  12
# #####################################
# Data #36
# Model Prediction:  9.332246097177846
# Input Data:  [ 8 10  2  0  4]
# Real Label:  9
# #####################################
# Data #37
# Model Prediction:  10.170251303418123
# Input Data:  [ 8 11  2  0  0]
# Real Label:  11
# #####################################
# Data #38
# Model Prediction:  9.663725551586968
# Input Data:  [ 7 10  2  1 25]
# Real Label:  11
# #####################################
# Data #39
# Model Prediction:  11.947738304965862
# Input Data:  [11 12  2  0 10]
# Real Label:  13
# #####################################
# Data #40
# Model Prediction:  9.74731683748433
# Input Data:  [10 10  1  0  2]
# Real Label:  10
# #####################################
